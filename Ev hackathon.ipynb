# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("dataset.csv")

# %%
df.head(2)
# Out:
#    VIN (1-10)  County      City State  Postal Code  Model Year       Make  \
# 0  JTMEB3FV6N  Monroe  Key West    FL      33040.0      2022.0     TOYOTA
# 1  1G1RD6E45D   Clark  Laughlin    NV      89029.0      2013.0  CHEVROLET
#
#         Model                   Electric Vehicle Type  \
# 0  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 1        VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible            42.0
# 1           Clean Alternative Fuel Vehicle Eligible            38.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0        0.0                   NaN     198968248.0
# 1        0.0                   NaN       5204412.0
#
#               Vehicle Location Electric Utility  2020 Census Tract
# 0    POINT (-81.80023 24.5545)              NaN       1.208797e+10
# 1  POINT (-114.57245 35.16815)              NaN       3.200301e+10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8857 entries, 0 to 8856
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   VIN (1-10)                                         8857 non-null   object
#  1   County                                             8857 non-null   object
#  2   City                                               8857 non-null   object
#  3   State                                              8856 non-null   object
#  4   Postal Code                                        8856 non-null   float64
#  5   Model Year                                         8856 non-null   float64
#  6   Make                                               8856 non-null   object
#  7   Model                                              8856 non-null   object
# ...

# %%
df.describe().T
# Out:
#                        count          mean           std           min  \
# Postal Code           8856.0  9.811858e+04  2.984219e+03  6.443000e+03
# Model Year            8856.0  2.018990e+03  2.856756e+00  2.010000e+03
# Electric Range        8856.0  8.957306e+01  1.026850e+02  0.000000e+00
# Base MSRP             8856.0  1.721235e+03  1.056362e+04  0.000000e+00
# Legislative District  8827.0  2.988388e+01  1.484282e+01  1.000000e+00
# DOL Vehicle ID        8856.0  1.990184e+08  9.376543e+07  2.770200e+04
# 2020 Census Tract     8856.0  5.294213e+10  1.896853e+09  6.013351e+09
#
#                                25%           50%           75%           max
# Postal Code           9.804200e+04  9.811800e+04  9.837200e+04  9.940300e+04
# Model Year            2.017000e+03  2.020000e+03  2.021000e+03  2.023000e+03
# Electric Range        0.000000e+00  3.500000e+01  2.080000e+02  3.370000e+02
# Base MSRP             0.000000e+00  0.000000e+00  0.000000e+00  1.844000e+05
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                            0
# County                                                0
# City                                                  0
# State                                                 1
# Postal Code                                           1
# Model Year                                            1
# Make                                                  1
# Model                                                 1
# Electric Vehicle Type                                 1
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     1
# Electric Range                                        1
# Base MSRP                                             1
# Legislative District                                 30
# DOL Vehicle ID                                        1
# Vehicle Location                                      2
# Electric Utility                                     46
# 2020 Census Tract                                     1
# ...

# %%
#there are some missing values

# %%
df.shape
# Out:
# (8857, 17)

# %%
df.dropna(inplace=True)

# %%
df['Model'].unique()
# Out:
# array(['RAV4 PRIME', 'VOLT', 'LEAF', 'BOLT EV', 'FUSION', 'MODEL 3',
#        'SOUL', 'Q5 E', 'MODEL X', '500', 'X5', '530E', 'TAYCAN', 'X3',
#        'A3', 'SOUL EV', 'C-MAX', 'MODEL S', 'F-150', 'CT6', 'I3',
#        'CLARITY', 'MODEL Y', 'NIRO', 'OUTLANDER', 'PACIFICA', 'R1T',
#        'KONA ELECTRIC', 'XC40', 'ID.4', 'PRIUS PLUG-IN', 'MUSTANG MACH-E',
#        'EQB-CLASS', 'E-GOLF', 'PRIUS PRIME', 'C40', 'SORENTO', 'XC60',
#        'CAYENNE', 'WRANGLER', 'COUNTRYMAN', 'S60', 'EV6',
#        'FORTWO ELECTRIC DRIVE', 'GRAND CHEROKEE', '330E', 'CROSSTREK',
#        'IONIQ 5', 'IONIQ', 'E-TRON', 'ROADSTER', 'KONA', 'XC90', 'SPARK',
#        'PS2', 'A7', 'HARDTOP', 'ESCAPE', 'LUCID AIR', 'E-TRON SPORTBACK',
#        'Q5', 'RAV4', 'AVIATOR', 'E-TRON GT', 'EDV', 'IX', 'FORTWO',
#        'I-PACE', 'SANTA FE', 'B-CLASS', 'KARMA', 'I4', 'OPTIMA',
#        'GLC-CLASS', 'Q4', 'SONATA', 'EQ FORTWO', 'FOCUS',
#        'RANGE ROVER SPORT', 'TRANSIT', 'PANAMERA', 'I8', 'BOLT EUV',
# ...

# %%
df['Model'].value_counts()
# Out:
# MODEL 3    1785
# MODEL Y    1365
# LEAF       1006
# MODEL S     564
# BOLT EV     440
#            ...
# 740E          2
# S-CLASS       2
# I-MIEV        1
# CITY          1
# S90           1
# Name: Model, Length: 97, dtype: int64

# %%
#Most of the electric cars belong to model3

# %%
df.loc[df['Model']=='MODEL 3']['Make']
# Out:
# 5       TESLA
# 14      TESLA
# 20      TESLA
# 26      TESLA
# 32      TESLA
#         ...
# 8826    TESLA
# 8833    TESLA
# 8840    TESLA
# 8850    TESLA
# 8854    TESLA
# Name: Make, Length: 1785, dtype: object

# %%
df.loc[df['Model']=='MODEL 3']['Model Year']
# Out:
# 5       2018.0
# 14      2018.0
# 20      2018.0
# 26      2020.0
# 32      2019.0
#          ...
# 8826    2020.0
# 8833    2020.0
# 8840    2018.0
# 8850    2019.0
# 8854    2022.0
# Name: Model Year, Length: 1785, dtype: float64

# %%
#Model 3 is being manufactured by tesla from 2018 to 2022

# %%
df['Postal Code'].unique()
# Out:
# array([33040., 89029., 98901., 98237., 98201., 98021., 98203., 98275.,
#        98236., 98221., 98516., 98837., 62258., 98579., 98233., 98344.,
#        98271., 98037., 12833., 98026., 99026., 98502., 98087., 98125.,
#        98001., 98115., 98020., 98260., 98503., 98501., 98208., 98296.,
#        98312., 98036., 98204., 23602., 98902., 98908., 73521., 99163.,
#        60035., 99205., 98392., 98272., 98382., 98345., 98513., 60031.,
#        98038., 98270., 98031., 98155., 98370., 98290., 98052., 98029.,
#        98632., 98406., 98926., 98168., 98329., 98373., 98074., 98102.,
#        98595., 98683., 98011., 99001., 98075., 98040., 98292., 98053.,
#        98110., 98032., 98112., 98122., 98116., 98002., 98822., 98498.,
#        98391., 98106., 98402., 98008., 98663., 99212., 98033., 98144.,
#        98446., 98107., 98059., 98367., 98225., 98661., 99354., 98004.,
#        98282., 98801., 98103., 98178., 98258., 98684., 98686., 98229.,
# ...

# %%
len(df['Postal Code'].unique())
# Out:
# 411

# %%
df['Postal Code'].value_counts()
# Out:
# 98052.0    254
# 98034.0    203
# 98004.0    195
# 98501.0    193
# 98033.0    179
#           ...
# 98850.0      1
# 99118.0      1
# 98856.0      1
# 98582.0      1
# 99130.0      1
# Name: Postal Code, Length: 410, dtype: int64

# %%
#more number of vehicles belong to postal code 98052

# %%
df['Make'].value_counts()
# Out:
# TESLA            4076
# NISSAN           1006
# CHEVROLET         863
# FORD              479
# TOYOTA            352
# BMW               340
# KIA               327
# AUDI              189
# VOLKSWAGEN        187
# VOLVO             186
# CHRYSLER          126
# HYUNDAI           116
# RIVIAN             74
# JEEP               72
# MITSUBISHI         71
# FIAT               69
# HONDA              64
# PORSCHE            56
# MINI               46
# MERCEDES-BENZ      40
# POLESTAR           38
# SMART              20
# JAGUAR             17
# LINCOLN            15
# SUBARU              6
# LUCID MOTORS        6
# CADILLAC            5
# FISKER              3
# LAND ROVER          3
# LEXUS               3
# TH!NK               1
# Name: Make, dtype: int64

# %%
px.bar(df['Make'].value_counts()[:20]).update_layout(
    xaxis_title="Make", yaxis_title="Value counts")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(df,x='Make')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Tesla is the highest producer of EV with count of 4076

# %%
Companies = df.groupby('Make').count().sort_values(by='City',ascending=False)['City'].index
top_10_companies = list(Companies)[:10]
for i in top_10_companies:
    data = df[df['Make']==i]
    data = data.groupby('Model').count().sort_values(by='City',ascending=False).index
    print('Top selling model for',i,'is ----------->',data[0])
# Out:
# Top selling model for TESLA is -----------> MODEL 3
# Top selling model for NISSAN is -----------> LEAF
# Top selling model for CHEVROLET is -----------> BOLT EV
# Top selling model for FORD is -----------> FUSION
# Top selling model for TOYOTA is -----------> PRIUS PRIME
# Top selling model for BMW is -----------> I3
# Top selling model for KIA is -----------> NIRO
# Top selling model for AUDI is -----------> E-TRON
# Top selling model for VOLVO is -----------> XC90
# Top selling model for VOLKSWAGEN is -----------> ID.4

# %%
tesla = df.groupby('City')['Model Year'].max().sort_values(ascending=False)

# %%
px.bar(tesla.head(10)).update_layout(
    xaxis_title="City", yaxis_title="Value counts")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df[df['Make']== 'TESLA']['Model'].unique()
# Out:
# array(['MODEL 3', 'MODEL X', 'MODEL S', 'MODEL Y', 'ROADSTER'],
#       dtype=object)

# %%
#'MODEL 3', 'MODEL X', 'MODEL S', 'MODEL Y', 'ROADSTER' are the models from tesla

# %%
models = df[df['Make']== 'TESLA']['Model'].value_counts()

# %%
models
# Out:
# MODEL 3     1774
# MODEL Y     1360
# MODEL S      559
# MODEL X      355
# ROADSTER       4
# Name: Model, dtype: int64

# %%
px.pie(names=models.index, values=models.values, hole=0.6, title='Models')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['City'].unique()
# Out:
# array(['Key West', 'Laughlin', 'Yakima', 'Concrete', 'Everett', 'Bothell',
#        'Mukilteo', 'Clinton', 'Anacortes', 'Lacey', 'Moses Lake',
#        'Mascoutah', 'Rochester', 'Burlington', 'Kapowsin', 'Marysville',
#        'Lynnwood', 'Greenfield Center', 'Edmonds', 'Nine Mile Falls',
#        'Olympia', 'Seattle', 'Auburn', 'Langley', 'Snohomish',
#        'Bremerton', 'Newport News', 'Altus', 'Pullman', 'Highland Park',
#        'Spokane', 'Suquamish', 'Monroe', 'Sequim', 'Keyport', 'Gurnee',
#        'Maple Valley', 'Kent', 'Lake Forest Park', 'Poulsbo', 'Redmond',
#        'Issaquah', 'Longview', 'Tacoma', 'Ellensburg', 'Burien',
#        'Gig Harbor', 'South Hill', 'Sammamish', 'Westport', 'Vancouver',
#        'Airway Heights', 'Mercer Island', 'Stanwood', 'Tumwater',
#        'Bainbridge Island', 'Entiat', 'Lakewood', 'Lake Tapps',
#        'Bellevue', 'Kirkland', 'Newcastle', 'Port Orchard', 'Bellingham',
# ...

# %%
df['City'].value_counts()
# Out:
# Seattle        1526
# Bellevue        511
# Kirkland        379
# Redmond         359
# Vancouver       334
#                ...
# Hoquiam           1
# St John           1
# Rock Island       1
# Artondale         1
# Bo                1
# Name: City, Length: 312, dtype: int64

# %%
px.bar(df['City'].value_counts()[:20]).update_layout(
    xaxis_title="City", yaxis_title="Value counts")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['County'].unique()
# Out:
# array(['Monroe', 'Clark', 'Yakima', 'Skagit', 'Snohomish', 'Island',
#        'Thurston', 'Grant', 'St. Clair', 'Pierce', 'Saratoga', 'Stevens',
#        'King', 'Kitsap', 'Newport News', 'Jackson', 'Whitman', 'Lake',
#        'Spokane', 'Clallam', 'Cowlitz', 'Kittitas', 'Grays Harbor',
#        'Chelan', 'Whatcom', 'Benton', 'Walla Walla', 'Mason', 'San Juan',
#        'Lewis', 'Jefferson', 'Douglas', 'Klickitat', 'Geary', 'Skamania',
#        'Fairfax', 'Adams', 'Franklin', 'Okanogan', 'Sonoma', 'Asotin',
#        'Ferry', 'Pacific', 'Riverside', 'Orange', 'Columbia', 'Wahkiakum',
#        'Leavenworth', 'Contra Costa', 'Howard', 'Larimer',
#        'District of Columbia', 'Washington', 'Tipton', 'San Diego',
#        'Sumter', "Prince George's", 'New Haven', 'Lincoln', 'Las Animas',
#        'Frederick'], dtype=object)

# %%
df['County'].value_counts()
# Out:
# King            4642
# Snohomish        987
# Pierce           631
# Clark            523
# Thurston         415
#                 ...
# Jackson            1
# Newport News       1
# Saratoga           1
# St. Clair          1
# Frederick          1
# Name: County, Length: 61, dtype: int64

# %%
px.bar(df['County'].value_counts()).update_layout(
    xaxis_title="County", yaxis_title="Value counts")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['Model Year'].unique()
# Out:
# array([2011., 2017., 2019., 2018., 2013., 2016., 2020., 2021., 2022.,
#        2015., 2014., 2012., 2023., 2010.])

# %%
my = df['Model Year'].value_counts()
# Out:
# Float64Index([2022.0, 2021.0, 2018.0, 2020.0, 2019.0, 2017.0, 2016.0, 2015.0,
#               2013.0, 2014.0, 2023.0, 2012.0, 2011.0, 2010.0],
#              dtype='float64')

# %%
px.pie(names=my.index, values=my.values, hole=0.6, title='Model year')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(df, x="Electric Range", y="Base MSRP")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dist =pd.DataFrame(df.groupby('Make')['Electric Range'].mean().reset_index()).sort_values(by='Electric Range',ascending=False).reset_index(drop=True).head(10)
dist.columns = ['model','range']
px.pie(dist, names='model', values='range',title='Top 10 Models with good milage',hole=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Jaguar cars have good milage.Though tesla cars are market leaders these cars lack behind i milage

# %%
px.imshow(df.corr())
# Out:
# <ipython-input-91-0dfbac1aba16>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(df,y='Electric Range',x='Make')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['Lattitude'] = df['Vehicle Location'].apply(lambda x:float(x.split(' ')[1][1:]))
df['Longitude'] = df['Vehicle Location'].apply(lambda x:float(x.split(' ')[2][:-1]))

# %%
px.scatter(df,x ='Lattitude',y = 'Longitude')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.choropleth(df,locations='State',locationmode="USA-states",color='Make')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pip install bar-chart-race
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 3.2 MB/s eta 0:00:00
# ...

# %%
import bar_chart_race as bcr

# %%
bcr.bar_chart_race(df = df,
                   n_bars = 6,
                   sort='desc',
                   title='Ev dataset',
                   filename = 'filename.mp4')
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:893: FutureWarning:
#
# Dropping of nuisance columns in DataFrame.rank is deprecated; in a future version this will raise TypeError. Select only valid columns before calling rank.
#
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:278: FutureWarning:
#
# The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
#
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
# ...
